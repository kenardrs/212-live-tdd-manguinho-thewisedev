# %% [markdown]
# <a href="https://colab.research.google.com/github/kenardrs/212-live-tdd-manguinho-thewisedev/blob/main/alura_pandas_transf_manip_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

hospedagem_url = 'https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_hospedagem.json'

# moveis_url = 'https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_moveis.json'

df_hospedagem = pd.read_json(hospedagem_url, lines=True)

# df_moveis = pd.read_json(moveis_url)

df_hospedagem
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-729a2d6e41a1> in <cell line: 7>()
#       5 # moveis_url = 'https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_moveis.json'
#       6
# ----> 7 df_hospedagem = pd.read_json(hospedagem_url, lines=True)
#       8
#       9 # df_moveis = pd.read_json(moveis_url)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     778         convert_axes = True
#     779
# --> 780     json_reader = JsonReader(
#     781         path_or_buf,
#     782         orient=orient,
#
# ...
